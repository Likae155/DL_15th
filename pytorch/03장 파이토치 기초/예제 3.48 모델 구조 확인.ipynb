# %% [markdown]
# # 예제 3.48: 모델 구조 확인
#
# ## 학습목표
# 1. **저장된 모델의 구조** 확인하는 방법 익히기
# 2. **모델 전체 저장 방식**의 특징 이해하기
#
# ---
#
# #### 모델 클래스 정의 (빈 클래스)
#
# **참고**: 모델 전체를 저장하면 클래스 정의만 있으면 불러올 수 있음

# %%
import torch
from torch import nn

# 빈 클래스 정의 (구조만 있으면 됨)
class CustomModel(nn.Module):
    pass

# %% [markdown]
# ---
#
# #### 모델 불러와서 구조 확인

# %%
# 저장된 모델 불러오기
device = "cuda" if torch.cuda.is_available() else "cpu"
model = torch.load("../models/model.pt", map_location=device)

# 모델 구조 출력 - 레이어 정보 확인 가능
print(model)
